# %% [markdown]
# ## Project Title:    Amazon Sales Data Analysis
# ## Technologies:  Business Intelligence
# ## Domain:  E-commerce
# ## Difficulty Level:  Advanced

# %% [markdown]
# #### PROBLEM STATEMENT

# %% [markdown]
# Sales management has gained importance to meet increasing competition and the need for improved methods of distribution to reduce cost and to increase profits. Sales
# management today is the most important function in a commercial and business enterprise.
#
# Do ETL : Extract-Transform-Load some Amazon dataset and find Sales-trend -> month wise , year wise , yearly_month wise.
#
# Find key metrics and factors and show the meaningful relationships between attributes.

# %% [markdown]
# #### DATA COLLECTION

# %% [markdown]
# Dataset taken from iNeuron Portal Link - https://drive.google.com/drive/folders/1FkmFVL8wlJmQWP1z52TD8PlhOJhitTyI?usp=sharing

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd #Data Manipulation and Analysis
import numpy as np #Numerical Computing
import matplotlib.pyplot as plt  #Data Visualization
# %matplotlib inline
import seaborn as sns  #Data Visualization
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing data
sales = pd.read_csv(r'C:\Users\kusha\OneDrive\Desktop\New folder\SALESDATA.csv')
sales.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0   4/30/2017          -237.91   2017/04/30        100012.0
# 1  10002220.0   7/14/2017           368.79   2017/07/14        100233.0
# 2  10002220.0  10/17/2017           109.73   2017/10/17        116165.0
# 3  10002489.0    6/3/2017          -211.75   2017/06/03        100096.0
# 4  10004516.0   5/27/2017         96627.94   2017/05/27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  ...  Sales Cost Amount Sales Margin Amount  Sales Price  \
# 0        0.00  ...                0.0              237.91   237.910000
# 1      824.96  ...                0.0              456.17   456.170000
# 2      548.66  ...                0.0              438.93   438.930000
# 3        0.00  ...                0.0              211.75   211.750000
# 4      408.52  ...                0.0            89248.66   196.150901
#
#    Sales Quantity  Sales Rep  U/M  Unnamed: 20  \
# 0             1.0      184.0   EA          NaN
# 1             1.0      127.0   EA          NaN
# 2             1.0      127.0   EA          NaN
# 3             1.0      160.0   EA          NaN
# 4           455.0      124.0   SE          NaN
#
#                              Unnamed: 21  Unnamed: 22 Unnamed: 23
# 0                  U/M = unit of measure          NaN         NaN
# 1                                    NaN          NaN         NaN
# 2                              EA = each          NaN         NaN
# 3                                    NaN          NaN         NaN
# 4  SE = some SI unit like kgs or gallons          NaN         NaN
#
# [5 rows x 24 columns]

# %%
#Checking the total amount of rows and columns
sales.shape
# Out:
# (65535, 24)

# %%
#Information about the dataset
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65282 non-null  float64
#  1   DateKey                           65282 non-null  object
#  2   Discount Amount                   65280 non-null  float64
#  3   Invoice Date                      65282 non-null  object
#  4   Invoice Number                    65282 non-null  float64
#  5   Item Class                        56993 non-null  object
#  6   Item Number                       65241 non-null  object
#  7   Item                              65282 non-null  object
#  8   Line Number                       65282 non-null  float64
#  9   List Price                        65282 non-null  float64
#  10  Order Number                      65282 non-null  float64
#  11  Promised Delivery Date            65282 non-null  object
#  12  Sales Amount                      65282 non-null  float64
#  13  Sales Amount Based on List Price  65282 non-null  float64
#  14  Sales Cost Amount                 65282 non-null  float64
#  15  Sales Margin Amount               65282 non-null  float64
#  16  Sales Price                       65281 non-null  float64
#  17  Sales Quantity                    65282 non-null  float64
#  18  Sales Rep                         65282 non-null  float64
#  19  U/M                               65282 non-null  object
#  20  Unnamed: 20                       0 non-null      float64
#  21  Unnamed: 21                       4 non-null      object
#  22  Unnamed: 22                       0 non-null      float64
#  23  Unnamed: 23                       0 non-null      float64
# dtypes: float64(16), object(8)
# memory usage: 12.0+ MB

# %%
#Dropping unnecessary columns
sales = sales.drop(columns=['Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','DateKey','Item Class','Item Number','Line Number','Order Number','Invoice Number'], axis=1)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65282 non-null  float64
#  1   Discount Amount                   65280 non-null  float64
#  2   Invoice Date                      65282 non-null  object
#  3   Item                              65282 non-null  object
#  4   List Price                        65282 non-null  float64
#  5   Promised Delivery Date            65282 non-null  object
#  6   Sales Amount                      65282 non-null  float64
#  7   Sales Amount Based on List Price  65282 non-null  float64
#  8   Sales Cost Amount                 65282 non-null  float64
#  9   Sales Margin Amount               65282 non-null  float64
#  10  Sales Price                       65281 non-null  float64
#  11  Sales Quantity                    65282 non-null  float64
#  12  Sales Rep                         65282 non-null  float64
#  13  U/M                               65282 non-null  object
# dtypes: float64(10), object(4)
# memory usage: 7.0+ MB

# %%
#Changing data types of Date columns
sales['Invoice Date'] = pd.to_datetime(sales['Invoice Date'])
sales['Promised Delivery Date'] = pd.to_datetime(sales['Promised Delivery Date'])
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65282 non-null  float64
#  1   Discount Amount                   65280 non-null  float64
#  2   Invoice Date                      65282 non-null  datetime64[ns]
#  3   Item                              65282 non-null  object
#  4   List Price                        65282 non-null  float64
#  5   Promised Delivery Date            65282 non-null  datetime64[ns]
#  6   Sales Amount                      65282 non-null  float64
#  7   Sales Amount Based on List Price  65282 non-null  float64
#  8   Sales Cost Amount                 65282 non-null  float64
#  9   Sales Margin Amount               65282 non-null  float64
#  10  Sales Price                       65281 non-null  float64
#  11  Sales Quantity                    65282 non-null  float64
#  12  Sales Rep                         65282 non-null  float64
#  13  U/M                               65282 non-null  object
# dtypes: datetime64[ns](2), float64(10), object(2)
# memory usage: 7.0+ MB

# %%
#Removing null rows
sales = sales.dropna(axis=0)
sales.isnull().sum()
# Out:
# CustKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Item                                0
# List Price                          0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# dtype: int64

# %%
sales['Invoice Year'] = pd.to_datetime(sales['Invoice Date']).dt.year
sales['Invoice Month'] = pd.to_datetime(sales['Invoice Date']).dt.month
sales['Invoice Quarter'] = pd.to_datetime(sales['Invoice Date']).dt.quarter
sales['Invoice Day'] = pd.to_datetime(sales['Invoice Date']).dt.day

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65280 entries, 0 to 65281
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           65280 non-null  float64
#  1   Discount Amount                   65280 non-null  float64
#  2   Invoice Date                      65280 non-null  datetime64[ns]
#  3   Item                              65280 non-null  object
#  4   List Price                        65280 non-null  float64
#  5   Promised Delivery Date            65280 non-null  datetime64[ns]
#  6   Sales Amount                      65280 non-null  float64
#  7   Sales Amount Based on List Price  65280 non-null  float64
#  8   Sales Cost Amount                 65280 non-null  float64
#  9   Sales Margin Amount               65280 non-null  float64
#  10  Sales Price                       65280 non-null  float64
#  11  Sales Quantity                    65280 non-null  float64
#  12  Sales Rep                         65280 non-null  float64
#  13  U/M                               65280 non-null  object
#  14  Invoice Year                      65280 non-null  int32
#  15  Invoice Month                     65280 non-null  int32
#  16  Invoice Quarter                   65280 non-null  int32
#  17  Invoice Day                       65280 non-null  int32
# dtypes: datetime64[ns](2), float64(10), int32(4), object(2)
# memory usage: 8.5+ MB

# %%
sales.head()
# Out:
#       CustKey  Discount Amount Invoice Date                             Item  \
# 0  10000481.0          -237.91   2017-04-30                 Urban Large Eggs
# 1  10002220.0           368.79   2017-07-14               Moms Sliced Turkey
# 2  10002220.0           109.73   2017-10-17  Cutting Edge Foot-Long Hot Dogs
# 3  10002489.0          -211.75   2017-06-03                         Kiwi Lox
# 4  10004516.0         96627.94   2017-05-27             High Top Sweet Onion
#
#    List Price Promised Delivery Date  Sales Amount  \
# 0        0.00             2017-04-30        237.91
# 1      824.96             2017-07-14        456.17
# 2      548.66             2017-10-16        438.93
# 3        0.00             2017-06-03        211.75
# 4      408.52             2017-05-28      89248.66
#
#    Sales Amount Based on List Price  Sales Cost Amount  Sales Margin Amount  \
# 0                              0.00                0.0               237.91
# 1                            824.96                0.0               456.17
# 2                            548.66                0.0               438.93
# 3                              0.00                0.0               211.75
# 4                         185876.60                0.0             89248.66
#
#    Sales Price  Sales Quantity  Sales Rep U/M  Invoice Year  Invoice Month  \
# 0   237.910000             1.0      184.0  EA          2017              4
# 1   456.170000             1.0      127.0  EA          2017              7
# 2   438.930000             1.0      127.0  EA          2017             10
# 3   211.750000             1.0      160.0  EA          2017              6
# 4   196.150901           455.0      124.0  SE          2017              5
#
#    Invoice Quarter  Invoice Day
# 0                2           30
# 1                3           14
# 2                4           17
# 3                2            3
# 4                2           27

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Assuming 'sales' is your DataFrame
# # Identify non-numeric columns
# non_numeric_columns = sales.select_dtypes(exclude=['float64', 'int64']).columns

# # Exclude non-numeric columns from correlation calculation
# numeric_columns = sales.columns.difference(non_numeric_columns)
# correlation_data = sales[numeric_columns]

# # # Plot correlation matrix
# # plt.figure(figsize=(20, 10))
# # sns.heatmap(correlation_data.corr(), annot=True)
# # plt.show()

# %%
sales.to_csv('CleanedAmazonSalesData.csv')
